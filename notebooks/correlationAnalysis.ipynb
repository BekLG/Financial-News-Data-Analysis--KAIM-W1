# %%
import pandas as pd
from textblob import TextBlob
import nltk
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load datasets

# %%
news_data = pd.read_csv('../data/raw_analyst_ratings.csv')
stock_data = pd.read_csv('../data/yfinance_data/GOOG_historical_data.csv')

# %% [markdown]
# #### Convert date columns to datetime

# %%
news_data['date'] = pd.to_datetime(news_data['date'], errors='coerce', format='%Y-%m-%d %H:%M:%S')
stock_data['Date'] = pd.to_datetime(stock_data['Date'], errors='coerce')

# %% [markdown]
# #### Filter news for Google (ticker 'GOOGL')

# %%
google_news = news_data[news_data['stock'] == 'GOOG'].copy()  
google_news
# Out:
#         Unnamed: 0                                           headline  \
# 565380      568379  Facebook, Snap Analyst Projects Q2 Revenue Ups...
# 565381      568380  How Cannabis Company Cannaphyll Is Marketing O...
# 565382      568381  Twitter, Square Will Mark Juneteenth As Holida...
# 565383      568382             Price Over Earnings Overview: Alphabet
# 565384      568383  Google Maps To Offer Relevant Local COVID-19 I...
# ...            ...                                                ...
# 566574      569584  Loup's Munster On Alphabet/Google Notes Short-...
# 566575      569585  Moderate Inflation, Positive Retail Earnings O...
# 566576      569586  UPDATE: JANA Partners 13F Shows Fund Liquidate...
# 566577      569587  Startup Point Of Sale Operating System Poynt R...
# 566578      569588  Day After Selloff, Earnings, Trade News Seem T...
#
#                                                       url          publisher  \
# 565380  https://www.benzinga.com/analyst-ratings/analy...   Shanthi Rexaline
# 565381  https://www.benzinga.com/markets/cannabis/20/0...        Jaycee Tenn
# 565382  https://www.benzinga.com/news/20/06/16218441/t...  Shivdeep Dhaliwal
# 565383  https://www.benzinga.com/intraday-update/20/06...  Benzinga Insights
# 565384  https://www.benzinga.com/news/20/06/16208274/g...  Shivdeep Dhaliwal
# ...                                                   ...                ...
# 566574  https://www.benzinga.com/analyst-ratings/analy...  Benzinga Newsdesk
# 566575  https://www.benzinga.com/news/earnings/18/11/1...         JJ Kinahan
# 566576  https://www.benzinga.com/news/18/11/12696718/u...  Benzinga Newsdesk
# 566577  https://www.benzinga.com/fintech/18/11/1268071...      Spencer White
# 566578  https://www.benzinga.com/news/earnings/18/11/1...         JJ Kinahan
#
#              date stock
# 565380        NaT  GOOG
# 565381        NaT  GOOG
# 565382        NaT  GOOG
# 565383        NaT  GOOG
# 565384        NaT  GOOG
# ...           ...   ...
# 566574 2018-11-15  GOOG
# 566575 2018-11-14  GOOG
# 566576 2018-11-14  GOOG
# 566577 2018-11-13  GOOG
# 566578 2018-11-13  GOOG
#
# [1199 rows x 6 columns]

# %%
# Identify rows with NaT in the date column
problematic_rows = google_news[google_news['date'].isna()]
print(len(problematic_rows))
# Out:
# 10

# %%
google_news = google_news.dropna(subset=['date']).copy()
print(len(google_news))
# Out:
# 1189

# %%
google_news
# Out:
#         Unnamed: 0                                           headline  \
# 565390      568400  MoneyGram Shares Jump 50% As Western Union Rep...
# 565391      568401  The First Week of June Is All About the May's ...
# 565392      568402  The 'Real' S&P 500 And Why The Current Rally M...
# 565393      568403  UK Supply Chain Startup Beacon Raises $15M Fro...
# 565394      568404  'DOJ has interviewed multiple Google competito...
# ...            ...                                                ...
# 566574      569584  Loup's Munster On Alphabet/Google Notes Short-...
# 566575      569585  Moderate Inflation, Positive Retail Earnings O...
# 566576      569586  UPDATE: JANA Partners 13F Shows Fund Liquidate...
# 566577      569587  Startup Point Of Sale Operating System Poynt R...
# 566578      569588  Day After Selloff, Earnings, Trade News Seem T...
#
#                                                       url          publisher  \
# 565390  https://www.benzinga.com/m-a/20/06/16156730/mo...      Neer Varshney
# 565391  https://www.benzinga.com/news/earnings/20/06/1...       IAM Newswire
# 565392  https://www.benzinga.com/opinion/20/06/1614773...       Eric Mancini
# 565393  https://www.benzinga.com/news/20/06/16146470/u...      Neer Varshney
# 565394  https://www.benzinga.com/news/20/05/16140154/d...  Benzinga Newsdesk
# ...                                                   ...                ...
# 566574  https://www.benzinga.com/analyst-ratings/analy...  Benzinga Newsdesk
# 566575  https://www.benzinga.com/news/earnings/18/11/1...         JJ Kinahan
# 566576  https://www.benzinga.com/news/18/11/12696718/u...  Benzinga Newsdesk
# 566577  https://www.benzinga.com/fintech/18/11/1268071...      Spencer White
# 566578  https://www.benzinga.com/news/earnings/18/11/1...         JJ Kinahan
#
#              date stock
# 565390 2020-06-02  GOOG
# 565391 2020-06-01  GOOG
# 565392 2020-06-01  GOOG
# 565393 2020-06-01  GOOG
# 565394 2020-05-29  GOOG
# ...           ...   ...
# 566574 2018-11-15  GOOG
# 566575 2018-11-14  GOOG
# 566576 2018-11-14  GOOG
# 566577 2018-11-13  GOOG
# 566578 2018-11-13  GOOG
#
# [1189 rows x 6 columns]

# %% [markdown]
# #### Aggregate news headlines by date

# %%
google_news['date'] = google_news['date'].dt.date  
news_daily = google_news.groupby('date').size().reset_index(name='news_count')
google_news.head()
# Out:
#         Unnamed: 0                                           headline  \
# 565390      568400  MoneyGram Shares Jump 50% As Western Union Rep...
# 565391      568401  The First Week of June Is All About the May's ...
# 565392      568402  The 'Real' S&P 500 And Why The Current Rally M...
# 565393      568403  UK Supply Chain Startup Beacon Raises $15M Fro...
# 565394      568404  'DOJ has interviewed multiple Google competito...
#
#                                                       url          publisher  \
# 565390  https://www.benzinga.com/m-a/20/06/16156730/mo...      Neer Varshney
# 565391  https://www.benzinga.com/news/earnings/20/06/1...       IAM Newswire
# 565392  https://www.benzinga.com/opinion/20/06/1614773...       Eric Mancini
# 565393  https://www.benzinga.com/news/20/06/16146470/u...      Neer Varshney
# 565394  https://www.benzinga.com/news/20/05/16140154/d...  Benzinga Newsdesk
#
#               date stock
# 565390  2020-06-02  GOOG
# 565391  2020-06-01  GOOG
# 565392  2020-06-01  GOOG
# 565393  2020-06-01  GOOG
# 565394  2020-05-29  GOOG

# %%
news_daily.head()
# Out:
#          date  news_count
# 0  2018-11-13           2
# 1  2018-11-14           2
# 2  2018-11-15           4
# 3  2018-11-16           2
# 4  2018-11-17           1

# %% [markdown]
# #### Perform Sentiment Analysis

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/bek/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Perform sentiment analysis
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# Apply sentiment analysis to each headline
google_news['sentiment'] = google_news['headline'].apply(get_sentiment)
google_news.head()
# Out:
#         Unnamed: 0                                           headline  \
# 565390      568400  MoneyGram Shares Jump 50% As Western Union Rep...
# 565391      568401  The First Week of June Is All About the May's ...
# 565392      568402  The 'Real' S&P 500 And Why The Current Rally M...
# 565393      568403  UK Supply Chain Startup Beacon Raises $15M Fro...
# 565394      568404  'DOJ has interviewed multiple Google competito...
#
#                                                       url          publisher  \
# 565390  https://www.benzinga.com/m-a/20/06/16156730/mo...      Neer Varshney
# 565391  https://www.benzinga.com/news/earnings/20/06/1...       IAM Newswire
# 565392  https://www.benzinga.com/opinion/20/06/1614773...       Eric Mancini
# 565393  https://www.benzinga.com/news/20/06/16146470/u...      Neer Varshney
# 565394  https://www.benzinga.com/news/20/05/16140154/d...  Benzinga Newsdesk
#
#               date stock  sentiment
# 565390  2020-06-02  GOOG       0.00
# 565391  2020-06-01  GOOG       0.25
# 565392  2020-06-01  GOOG       0.10
# 565393  2020-06-01  GOOG       0.00
# 565394  2020-05-29  GOOG       0.00

# %%
# Aggregate sentiment scores by date
daily_sentiment = google_news.groupby('date')['sentiment'].mean().reset_index(name='avg_sentiment')
daily_sentiment['date'] = pd.to_datetime(daily_sentiment['date'], errors='coerce')
daily_sentiment.head()
# Out:
#         date  avg_sentiment
# 0 2018-11-13       0.000000
# 1 2018-11-14       0.056818
# 2 2018-11-15       0.109028
# 3 2018-11-16      -0.190000
# 4 2018-11-17       0.500000

# %% [markdown]
# #### Calculate Stock Movements

# %%
# Calculate daily returns
stock_data['daily_return'] = stock_data['Close'].pct_change() * 100  # Percentage change
stock_data.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 1 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 3 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 4 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
#
#    Dividends  Stock Splits  daily_return
# 0        0.0           0.0           NaN
# 1        0.0           0.0      7.942989
# 2        0.0           0.0      1.006362
# 3        0.0           0.0     -4.140766
# 4        0.0           0.0      1.077510

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5020 non-null   datetime64[ns]
#  1   Open          5020 non-null   float64
#  2   High          5020 non-null   float64
#  3   Low           5020 non-null   float64
#  4   Close         5020 non-null   float64
#  5   Adj Close     5020 non-null   float64
#  6   Volume        5020 non-null   int64
#  7   Dividends     5020 non-null   float64
#  8   Stock Splits  5020 non-null   float64
#  9   daily_return  5019 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 392.3 KB

# %%
daily_sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           372 non-null    datetime64[ns]
#  1   avg_sentiment  372 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.9 KB

# %%
merged_data = pd.merge(stock_data, daily_sentiment, left_on='Date', right_on='date', how='left')

# %%
merged_data.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 1 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 3 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 4 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
#
#    Dividends  Stock Splits  daily_return date  avg_sentiment
# 0        0.0           0.0           NaN  NaT            NaN
# 1        0.0           0.0      7.942989  NaT            NaN
# 2        0.0           0.0      1.006362  NaT            NaN
# 3        0.0           0.0     -4.140766  NaT            NaN
# 4        0.0           0.0      1.077510  NaT            NaN

# %%
merged_data['avg_sentiment'].fillna(0, inplace=True)
merged_data.dropna(subset=['daily_return'], inplace=True)
# Out:
# /tmp/ipykernel_93577/1834418008.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_data['avg_sentiment'].fillna(0, inplace=True)

# %%
merged_data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1    2004-08-20    2.515820    2.716817    2.503118    2.697639    2.694573
# 2    2004-08-23    2.758411    2.826406    2.716070    2.724787    2.721690
# 3    2004-08-24    2.770615    2.779581    2.579581    2.611960    2.608991
# 4    2004-08-25    2.614201    2.689918    2.587302    2.640104    2.637103
# 5    2004-08-26    2.613952    2.688672    2.606729    2.687676    2.684621
# ...         ...         ...         ...         ...         ...         ...
# 5015 2024-07-24  175.389999  177.949997  173.570007  174.369995  174.369995
# 5016 2024-07-25  174.250000  175.199997  169.050003  169.160004  169.160004
# 5017 2024-07-26  168.770004  169.839996  165.865005  168.679993  168.679993
# 5018 2024-07-29  170.500000  172.160004  169.720001  171.130005  171.130005
# 5019 2024-07-30  171.830002  172.949997  170.119995  171.860001  171.860001
#
#          Volume  Dividends  Stock Splits  daily_return date  avg_sentiment
# 1     458857488        0.0           0.0      7.942989  NaT            0.0
# 2     366857939        0.0           0.0      1.006362  NaT            0.0
# 3     306396159        0.0           0.0     -4.140766  NaT            0.0
# 4     184645512        0.0           0.0      1.077510  NaT            0.0
# 5     142572401        0.0           0.0      1.801895  NaT            0.0
# ...         ...        ...           ...           ...  ...            ...
# 5015   31250700        0.0           0.0     -5.027239  NaT            0.0
# 5016   28967900        0.0           0.0     -2.987894  NaT            0.0
# 5017   25150100        0.0           0.0     -0.283762  NaT            0.0
# 5018   13768900        0.0           0.0      1.452462  NaT            0.0
# 5019   13681400        0.0           0.0      0.426574  NaT            0.0
#
# [5019 rows x 12 columns]

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5019 entries, 1 to 5019
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           5019 non-null   datetime64[ns]
#  1   Open           5019 non-null   float64
#  2   High           5019 non-null   float64
#  3   Low            5019 non-null   float64
#  4   Close          5019 non-null   float64
#  5   Adj Close      5019 non-null   float64
#  6   Volume         5019 non-null   int64
#  7   Dividends      5019 non-null   float64
#  8   Stock Splits   5019 non-null   float64
#  9   daily_return   5019 non-null   float64
#  10  date           347 non-null    datetime64[ns]
#  11  avg_sentiment  5019 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(1)
# memory usage: 509.7 KB

# %%
# Verify date alignment
print("Stock Dates Range:", stock_data['Date'].min(), "to", stock_data['Date'].max())
print("News Dates Range:", daily_sentiment['date'].min(), "to", daily_sentiment['date'].max())

# Check for common dates
common_dates = set(stock_data['Date']).intersection(set(daily_sentiment['date']))
print("Common Dates Count:", len(common_dates))

# Check for missing dates in the news data
missing_dates = set(stock_data['Date']) - set(daily_sentiment['date'])
print("Missing Dates in News Data:", len(missing_dates))
# Out:
# Stock Dates Range: 2004-08-19 00:00:00 to 2024-07-30 00:00:00
# News Dates Range: 2018-11-13 00:00:00 to 2020-06-02 00:00:00
# Common Dates Count: 347
# Missing Dates in News Data: 4673

# %%
# Ensure 'Date' is in datetime format
merged_data['Date'] = pd.to_datetime(merged_data['Date'], errors='coerce')

# Create a new column for the year or month to use as a hue
merged_data['Year'] = merged_data['Date'].dt.year

# Set the size of the plot
plt.figure(figsize=(12, 6))

# Create a scatter plot with a regression line and color by Year
sns.scatterplot(x='daily_return', y='avg_sentiment', hue='Year', data=merged_data, palette='tab10', s=50)

# Add labels and title
plt.xlabel('Daily Return (%)')
plt.ylabel('Average Sentiment')
plt.title('Correlation between Daily Return and Average Sentiment by Year')

# Display the legend
plt.legend(title='Year')

# Show the plot
plt.show()
